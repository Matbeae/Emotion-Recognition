# %% [markdown]
# <a href="https://colab.research.google.com/github/Matbeae/Emotion-Recognition/blob/main/Untitled30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
# import pandas as pd
# import os
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
# import keras
# from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D,Dense,Dropout,BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# import cv2
# from tensorflow.keras.applications import VGG16, InceptionResNetV2
from keras import regularizers
# from tensorflow.keras.optimizers import Adam,RMSprop,SGD,Adamax
# from tensorflow.keras.metrics import top_k_categorical_accuracy
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# from tensorflow.keras import mixed_precision
# # mixed_precision.set_global_policy('mixed_float16')

# %%
# !cp -r "/content/drive/MyDrive/FER-2013" "/content/FER-2013"
# Out:
# ^C

# %%
train_dir = "/content/FER-2013/train"
test_dir  = "/content/FER-2013/test"

# %%
train_datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.12,
    height_shift_range=0.12,
    zoom_range=0.12,
    shear_range=0.12,
    brightness_range=(0.7,1.3),
    horizontal_flip=True,
    rescale=1./255,
    validation_split=0.2
)


test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(48,48),
    batch_size=64,
    color_mode="grayscale",
    class_mode="categorical",
    subset="training"
)

val_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(48,48),
    batch_size=64,
    color_mode="grayscale",
    class_mode="categorical",
    subset="validation"
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(48,48),
    batch_size=64,
    color_mode="grayscale",
    class_mode="categorical",
    shuffle=False
)
# Out:
# Found 22968 images belonging to 7 classes.
# Found 5741 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
# train_ds = tf.data.Dataset.from_generator(
#     lambda: train_generator,
#     output_signature=(
#         tf.TensorSpec(shape=(48,48,1), dtype=tf.float32),
#         tf.TensorSpec(shape=(7,), dtype=tf.float32),
#     )
# ).prefetch(tf.data.AUTOTUNE)

# val_ds = tf.data.Dataset.from_generator(
#     lambda: val_generator,
#     output_signature=(
#         tf.TensorSpec(shape=(48,48,1), dtype=tf.float32),
#         tf.TensorSpec(shape=(7,), dtype=tf.float32),
#     )
# ).prefetch(tf.data.AUTOTUNE)

# %%
model= tf.keras.models.Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', input_shape=(48, 48,1)))
model.add(Conv2D(64,(3,3), padding='same', activation='relu' ))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(5,5), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(128,(3,3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(256,(3,3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(1e-4)))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.3))

model.add(GlobalAveragePooling2D())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(512,activation = 'relu', kernel_regularizer=regularizers.l2(1e-4)))
model.add(BatchNormalization())
model.add(Dropout(0.15))

model.add(Dense(7, activation='softmax'))

opt = tf.keras.optimizers.Adam(learning_rate=3e-4)
# opt = mixed_precision.LossScaleOptimizer(opt)

# loss = tf.keras.losses.CategoricalCrossentropy()

model.compile(
    optimizer=opt,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
tf.keras.utils.plot_model(model, to_file='cnn_architecture.png', show_shapes=True, show_layer_names=True)

# %%
epochs = 100

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 48, 48, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 48, 48, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
# from sklearn.utils.class_weight import compute_class_weight

# classes = train_generator.classes  # np.array меток длиной n_samples
# class_weights = compute_class_weight(class_weight='balanced',
#                                      classes=np.unique(classes),
#                                      y=classes)
# class_weights = class_weights / np.mean(class_weights)
# class_weight = dict(enumerate(class_weights))
# print("class_weight:", class_weight)

# %%
early = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)

callbacks = [early, checkpoint, reduce_lr]

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.1766 - loss: 2.3348
# Epoch 1: val_loss improved from inf to 1.96406, saving model to best_model.keras
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 63s 118ms/step - accuracy: 0.1766 - loss: 2.3344 - val_accuracy: 0.2513 - val_loss: 1.9641 - learning_rate: 3.0000e-04
# Epoch 2/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.2120 - loss: 2.0247
# Epoch 2: val_loss improved from 1.96406 to 1.86693, saving model to best_model.keras
# ...

# %%
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
fig.set_size_inches(12,4)

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[0].set_title('Training Accuracy vs Validation Accuracy')
ax[0].set_ylabel('Accuracy')
ax[0].set_xlabel('Epoch')
ax[0].legend(['Train', 'Validation'], loc='upper left')

ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[1].set_title('Training Loss vs Validation Loss')
ax[1].set_ylabel('Loss')
ax[1].set_xlabel('Epoch')
ax[1].legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %%
# предсказания на валидации / тесте
test_generator.reset()
preds = model.predict(test_generator, verbose=1)
y_pred = np.argmax(preds, axis=1)
y_true = test_generator.classes

print(classification_report(y_true, y_pred, target_names=['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']))
cm = confusion_matrix(y_true, y_pred)
print(cm)
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step
#               precision    recall  f1-score   support
#
#        Angry       0.57      0.59      0.58       958
#      Disgust       0.70      0.41      0.51       111
#         Fear       0.58      0.34      0.43      1024
#        Happy       0.86      0.87      0.87      1774
#          Sad       0.53      0.73      0.62      1233
#     Surprise       0.55      0.51      0.53      1247
#      Neutral       0.75      0.78      0.77       831
#
#     accuracy                           0.65      7178
#    macro avg       0.65      0.61      0.61      7178
# weighted avg       0.66      0.65      0.65      7178
#
# [[ 566    6   67   28  154  112   25]
#  [  40   45    2    2    4   12    6]
#  [ 141    5  353   35  168  213  109]
#  [  37    0   23 1545  119   18   32]
#  [  56    4   22   79  905  142   25]
#  [ 130    2   70   66  326  630   23]
#  [  28    2   71   42   27    9  652]]

# %%
cm = confusion_matrix(y_true, y_pred)
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

plt.figure(figsize=(8,6))
sns.heatmap(cm_norm, annot=True, fmt='.2f',
            xticklabels=['A','D','F','H','S','Su','N'],
            yticklabels=['A','D','F','H','S','Su','N'])
plt.ylabel('True')
plt.xlabel('Pred')
plt.show()

# %%
# preds уже имеются (как ты сделал). y_pred, y_true.
errors = np.where(y_pred != y_true)[0]
for idx in errors[:50]:
    fn = test_generator.filepaths[idx]
    print("true:", test_generator.classes[idx], "pred:", y_pred[idx], fn)
# Out:
# true: 0 pred: 5 /content/FER-2013/test/angry/PrivateTest_1054527.jpg
# true: 0 pred: 5 /content/FER-2013/test/angry/PrivateTest_11296953.jpg
# true: 0 pred: 5 /content/FER-2013/test/angry/PrivateTest_12000629.jpg
# true: 0 pred: 4 /content/FER-2013/test/angry/PrivateTest_12766285.jpg
# true: 0 pred: 5 /content/FER-2013/test/angry/PrivateTest_1290484.jpg
# true: 0 pred: 4 /content/FER-2013/test/angry/PrivateTest_12912780.jpg
# true: 0 pred: 5 /content/FER-2013/test/angry/PrivateTest_13164119.jpg
# true: 0 pred: 2 /content/FER-2013/test/angry/PrivateTest_13463625.jpg
# true: 0 pred: 5 /content/FER-2013/test/angry/PrivateTest_13541561.jpg
# true: 0 pred: 4 /content/FER-2013/test/angry/PrivateTest_14482875.jpg
# true: 0 pred: 1 /content/FER-2013/test/angry/PrivateTest_14494003.jpg
# true: 0 pred: 4 /content/FER-2013/test/angry/PrivateTest_14596578.jpg
# true: 0 pred: 4 /content/FER-2013/test/angry/PrivateTest_14887556.jpg
# ...

# %%
train_loss, train_acc = model.evaluate(train_generator)
test_loss, test_acc   = model.evaluate(test_generator)
print("final train accuracy = {:.2f} , test accuracy = {:.2f}".format(train_acc*100, test_acc*100))
# Out:
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.7159 - loss: 0.8099
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6071 - loss: 1.0830
# final train accuracy = 71.89 , test accuracy = 65.42

# %%
# !rm -rf /content/FER-2013/FER-2013
# !rmdir /content/FER-2013/FER-2013

# %%
# !rm -rf /content/FER-2013/
